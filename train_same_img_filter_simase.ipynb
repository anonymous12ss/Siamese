# %%
import matplotlib.pyplot as plt

import numpy as np
import random
from PIL import Image
import os
import pandas as pd
from random import randint
import statistics
import torchvision
import torch
import torchvision.datasets as dset
import torchvision.transforms as transforms
import torchvision.utils
from torch.autograd import Variable  
from torch.utils import data
import torchvision.datasets as dset
from torch.utils.data import DataLoader,Dataset
from torch import optim

from siamese_new_classes import ContrastiveLossk, siamese_Dataset_no_mode, siamese_Dataset_filter_same_img
from siamese_new_network import PretrainedNet

#import wandb




class Config_ours():
    training_table = pd.read_csv('/mnt/recsys/daniel/datasets/ffhq_gan_generated_siamese_training/full_img_folders/csv_files/train_file.csv')
    testing_table = pd.read_csv('/mnt/recsys/daniel/datasets/ffhq_gan_generated_siamese_training/full_img_folders/csv_files/test_file.csv')
    image_dir = '/mnt/recsys/daniel/datasets/ffhq_gan_generated_siamese_training/full_img_folders'
    contrastive_margin = 2.5
    euclidean_distance_threshold = 1.0
    pretrained_model = 'resnet18'
    batch_size = 1
    optimizer = "adam"
    learning_rate = 0.0001
    contrastive_margin = 2.5
    epochs = 25

def build_dataset(batch_size, Config_ours):
   
    training_transforms = transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.5), # aim to train to be invariant to laterality of eye
    transforms.RandomRotation(15), # rotate +/- 5 degrees around center    # pixel crop
    transforms.ColorJitter(brightness = 0.5, contrast = 0.5), # brightness and color variation of +/- 5%
    transforms.RandomResizedCrop(size=(256, 256), scale=(0.8, 1.0)),
    transforms.ToTensor()
    ])

    validation_transforms = transforms.Compose([ # pixel crop
        transforms.ToTensor()
    ])
    
    
    training_siamese_dataset = siamese_Dataset_filter_same_img(patient_table = Config_ours.training_table, image_dir = Config_ours.image_dir)

    train_dataloader = torch.utils.data.DataLoader(training_siamese_dataset, batch_size=batch_size, shuffle=True, num_workers=0)

    testing_siamese_dataset = siamese_Dataset_filter_same_img(patient_table = Config_ours.testing_table, image_dir = Config_ours.image_dir)

    test_dataloader = torch.utils.data.DataLoader(testing_siamese_dataset, batch_size=1, shuffle=False, num_workers=0)
    return train_dataloader, test_dataloader

def build_optimizer(network, optimizer, learning_rate):
    if optimizer == "sgd":
        optimizer = optim.SGD(network.parameters(),
                              lr=learning_rate, momentum=0.9)
    elif optimizer == "adam":
        optimizer = optim.Adam(network.parameters(),
                               lr=learning_rate)
    return optimizer


def train(Config_ours):
    # Initialize a new wandb run

    # If called by wandb.agent, as below,
    # this config will be set by Sweep Controller


    train_dataloader, test_dataloader = build_dataset(Config_ours.batch_size, Config_ours)
    net = PretrainedNet(model= Config_ours.pretrained_model).cuda()
    optimizer = build_optimizer(net, Config_ours.optimizer, Config_ours.learning_rate)
    criterion = ContrastiveLossk(margin = Config_ours.contrastive_margin)


    for epoch in range(0,Config_ours.epochs):
        training_loss = 0

        #count = 0
        training_accuracy_history = []
        training_euclidean_distance_history = []
        training_label_history = []



        validation_accuracy_history = []
        validation_euclidean_distance_history = []
        validation_label_history = []

        net.train()
        print ('Starting training')
        for i, data in enumerate(train_dataloader,0):
            #print ('hi')
            img0, img1 , label, _ = data
            img0, img1 , label = img0.cuda(), img1.cuda(), label.cuda(),
            optimizer.zero_grad()
            output1, output2 = net.forward(img0,img1)
            loss_contrastive, euclidean_distance = criterion(output1,output2,label)
            loss_contrastive.backward()
            optimizer.step()
            training_loss += loss_contrastive.item()

            #print (training_loss)
            #if count % 100 == 0:
            #    print (training_loss/count)

            training_label = euclidean_distance > Config_ours.euclidean_distance_threshold
            equals = training_label.int().detach().cpu().numpy().flatten() == label.int().cpu().numpy()
            #acc_tmp = torch.Tensor.numpy(equals.cpu())
            training_accuracy_history.extend(equals)

            # save euclidean distance and label history 
            euclid_tmp = torch.Tensor.numpy(euclidean_distance.detach().cpu()) # detach gradient, move to CPU
            training_euclidean_distance_history.extend(euclid_tmp)
            label_tmp = torch.Tensor.numpy(label.cpu())
            training_label_history.extend(label_tmp)

            #count += 1

        else:
            validation_loss = 0
            count_correct_valid = 0

            label_0_distance_valid = 0; label_1_distance_valid = 0
            label_0_count_valid = 0;  label_1_count_valid = 0 


            net.eval() 
            print ("Starting Validation")
            with torch.no_grad():
                for i, data_v in enumerate(test_dataloader, 0):
                    img0_v, img1_v , label_v, _= data_v
                    img0_v, img1_v , label_v = img0_v.cuda(), img1_v.cuda() , label_v.cuda()
                    output_v1, output_v2 = net.forward(img0_v,img1_v)
                    loss_contrastive_v, euclidean_distance_v = criterion(output_v1, output_v2, label_v.float())
                    validation_loss += loss_contrastive_v.item()

                    testing_label = euclidean_distance_v > Config_ours.euclidean_distance_threshold
                    equals = testing_label.int().detach().cpu().numpy().flatten() == label_v.int().cpu().numpy()
                    validation_accuracy_history.extend(equals)

                    euclid_tmp = torch.Tensor.numpy(euclidean_distance_v.detach().cpu()) # detach gradient, move to CPU
                    validation_euclidean_distance_history.extend(euclid_tmp)
                    label_tmp = torch.Tensor.numpy(label_v.cpu())
                    validation_label_history.extend(label_tmp)




        training_accuracy = statistics.mean(np.array(training_accuracy_history).tolist())        
        euclid_if_0_t = [b for a, b in zip(training_label_history, training_euclidean_distance_history) if a == 0]
        euclid_if_1_t= [b for a, b in zip(training_label_history, training_euclidean_distance_history) if a == 1]
        euclid_if_0_t = np.array(euclid_if_0_t).flatten().tolist()
        euclid_if_1_t = np.array(euclid_if_1_t).flatten().tolist()

        # summary statistics for euclidean distances
        mean_euclid_0t = statistics.mean(euclid_if_0_t) 
        std_euclid_0t = statistics.pstdev(euclid_if_0_t)       
        mean_euclid_1t = statistics.mean(euclid_if_1_t)
        std_euclid_1t = statistics.pstdev(euclid_if_1_t)


        validation_accuracy = statistics.mean(np.array(validation_accuracy_history).tolist())        
        euclid_if_0_v = [b for a, b in zip(validation_label_history, validation_euclidean_distance_history) if a == 0]
        euclid_if_1_v= [b for a, b in zip(validation_label_history, validation_euclidean_distance_history) if a == 1]
        euclid_if_0_v = np.array(euclid_if_0_v).flatten().tolist()
        euclid_if_1_v = np.array(euclid_if_1_v).flatten().tolist()

        # summary statistics for euclidean distances
        mean_euclid_0v = statistics.mean(euclid_if_0_v) 
        std_euclid_0v = statistics.pstdev(euclid_if_0_v)       
        mean_euclid_1v = statistics.mean(euclid_if_1_v)
        std_euclid_1v = statistics.pstdev(euclid_if_1_v)

        training_loss_avg = training_loss/len(train_dataloader)
        validation_loss_avg = validation_loss/len(test_dataloader)
        #print (same_class_loss, count_same_class, other_class_loss, count_other_class)
        print("Epoch number {}\n Training loss {}\n Validation loss {}\n".format(epoch, training_loss_avg, validation_loss_avg))
        #print ("Same class loss{}\n same class count {} \n".format(same_class_loss.item()/count_same_class, count_same_class))
        #print ("Other class loss{}\n other class count {} \n".format(other_class_loss.item()/count_other_class, count_other_class))

        print ("Training Details")
        print ("training Accuracy = {}".format(training_accuracy))
        print ("Average Distance for 0 label = {}".format(mean_euclid_0t))
        print ("Average Distance for 1 label = {} \n".format(mean_euclid_1t))

        print ("Validation Details")
        print ("Validation Accuracy = {}".format(validation_accuracy))
        print ("Average Distance for 0 label = {}".format(mean_euclid_0v))
        print ("Average Distance for 1 label = {} \n".format(mean_euclid_1v))

        


        #counter.append(epoch)
        #Config.euclidean_distance_threshold = (mean_euclid_0v + mean_euclid_1v) / 2
        #training_loss_history.append(training_loss/len(train_dataloader))
        #validation_loss_history.append(validation_loss/len(test_dataloader))
        torch.save(net.state_dict(), checkpoints_dir + "/base_model_epoch{}.pth".format(epoch))


if __name__ == "__main__":
    

    os.environ['CUDA_VISIBLE_DEVICES']='3' # pick GPU to use
    use_cuda = torch.cuda.is_available()
    device = torch.device("cuda:3" if use_cuda else "cpu")

    checkpoints_dir = "./ckpt/{}".format('resnet_same')
    CkptisExist = os.path.exists(checkpoints_dir)
    if not CkptisExist:
       os.makedirs(checkpoints_dir)

    train(Config_ours)
# Out:
# Starting training
# Starting Validation
# Epoch number 0
#  Training loss 1.2157956139722603
#  Validation loss 103.72041671444671
#
# Training Details
# training Accuracy = 0.6778425655976676
# Average Distance for 0 label = 1.3415566560340255
# Average Distance for 1 label = 2.67609196140016
#
# Validation Details
# Validation Accuracy = 0.45454545454545453
# Average Distance for 0 label = 13.223254327420834
# Average Distance for 1 label = 26.420465596516927
#
# Starting training
# Starting Validation
# Epoch number 1
#  Training loss 0.18494554160708568
#  Validation loss 37.38662122475981
#
# Training Details
# training Accuracy = 0.9897959183673469
# Average Distance for 0 label = 0.5346931100336474
# Average Distance for 1 label = 3.4179379247192645
#
# Validation Details
# Validation Accuracy = 0.5353535353535354
# Average Distance for 0 label = 8.586238342782725
# Average Distance for 1 label = 24.131951116166025
#
# Starting training
# Starting Validation
# Epoch number 2
#  Training loss 0.09986353752659688
#  Validation loss 22.573472576912003
#
# Training Details
# training Accuracy = 0.9941690962099126
# Average Distance for 0 label = 0.34994520232962667
# Average Distance for 1 label = 3.4705017955060216
#
# Validation Details
# Validation Accuracy = 0.494949494949495
# Average Distance for 0 label = 6.318008871078491
# Average Distance for 1 label = 22.12329169682094
#
# Starting training
# Starting Validation
# Epoch number 3
#  Training loss 0.06750419496697083
#  Validation loss 19.97043814803615
#
# Training Details
# training Accuracy = 0.9941690962099126
# Average Distance for 0 label = 0.2708467884045659
# Average Distance for 1 label = 4.021655314758922
#
# Validation Details
# Validation Accuracy = 0.48484848484848486
# Average Distance for 0 label = 5.8673624337888235
# Average Distance for 1 label = 22.415495196978252
#
# Starting training
# Starting Validation
# Epoch number 4
#  Training loss 0.04986725407740802
#  Validation loss 11.865715168943309
#
# Training Details
# training Accuracy = 0.9956268221574344
# Average Distance for 0 label = 0.22891373443351665
# Average Distance for 1 label = 4.7075658264116935
#
# Validation Details
# Validation Accuracy = 0.5555555555555556
# Average Distance for 0 label = 4.807957332242619
# Average Distance for 1 label = 22.36960896578702
#
# Starting training
# Starting Validation
# Epoch number 5
#  Training loss 0.0533238150934219
#  Validation loss 6.092490829602636
#
# Training Details
# training Accuracy = 0.9941690962099126
# Average Distance for 0 label = 0.20045906562535537
# Average Distance for 1 label = 4.477697413265705
#
# Validation Details
# Validation Accuracy = 0.4444444444444444
# Average Distance for 0 label = 3.147551989555359
# Average Distance for 1 label = 18.668839194557883
#
# Starting training
# Starting Validation
# Epoch number 6
#  Training loss 0.03646148851330721
#  Validation loss 2.4567107588353783
#
# Training Details
# training Accuracy = 0.9956268221574344
# Average Distance for 0 label = 0.14775704717324986
# Average Distance for 1 label = 3.80625110077932
#
# Validation Details
# Validation Accuracy = 0.5656565656565656
# Average Distance for 0 label = 2.1982521851857504
# Average Distance for 1 label = 22.001450415010805
#
# Starting training
# Starting Validation
# Epoch number 7
#  Training loss 0.05188800888197122
#  Validation loss 2.4965856623167944
#
# Training Details
# training Accuracy = 0.9927113702623906
# Average Distance for 0 label = 0.12230254886065714
# Average Distance for 1 label = 4.078133750257307
#
# Validation Details
# Validation Accuracy = 0.5252525252525253
# Average Distance for 0 label = 2.1447046188016734
# Average Distance for 1 label = 21.59954501133339
#
# Starting training
# Starting Validation
# Epoch number 8
#  Training loss 0.03416391735358175
#  Validation loss 2.679546398947937
#
# Training Details
# training Accuracy = 0.9956268221574344
# Average Distance for 0 label = 0.10648618743358972
# Average Distance for 1 label = 4.466524388704618
#
# Validation Details
# Validation Accuracy = 0.494949494949495
# Average Distance for 0 label = 2.0700042832356234
# Average Distance for 1 label = 28.737183469407103
#
# Starting training
# Starting Validation
# Epoch number 9
#  Training loss 0.07868137824571075
#  Validation loss 3.7978295093835004
#
# Training Details
# training Accuracy = 0.9897959183673469
# Average Distance for 0 label = 0.15437895483886008
# Average Distance for 1 label = 4.6955281457850635
#
# Validation Details
# Validation Accuracy = 0.5151515151515151
# Average Distance for 0 label = 2.3581347489843565
# Average Distance for 1 label = 32.093836979866026
#
# Starting training
# Starting Validation
# Epoch number 10
#  Training loss 0.0837839991344701
#  Validation loss 4.548255564588489
#
# Training Details
# training Accuracy = 0.9868804664723032
# Average Distance for 0 label = 0.1677120736844483
# Average Distance for 1 label = 4.64178222996848
#
# Validation Details
# Validation Accuracy = 0.48484848484848486
# Average Distance for 0 label = 2.4802263751626015
# Average Distance for 1 label = 22.203812843145325
#
# Starting training
# Starting Validation
# Epoch number 11
#  Training loss 0.03501194676606119
#  Validation loss 1.1378796904376058
#
# Training Details
# training Accuracy = 0.9927113702623906
# Average Distance for 0 label = 0.10858421526175893
# Average Distance for 1 label = 5.091194746315305
#
# Validation Details
# Validation Accuracy = 0.6565656565656566
# Average Distance for 0 label = 1.4807656597007404
# Average Distance for 1 label = 31.55524288524281
#
# Starting training
# Starting Validation
# Epoch number 12
#  Training loss 0.10648212602487446
#  Validation loss 0.4783630509569187
#
# Training Details
# training Accuracy = 0.9825072886297376
# Average Distance for 0 label = 0.11628778223679866
# Average Distance for 1 label = 5.004508191955761
#
# Validation Details
# Validation Accuracy = 0.8181818181818182
# Average Distance for 0 label = 0.9252553770075673
# Average Distance for 1 label = 19.529880685626335
#
# Starting training
# Starting Validation
# Epoch number 13
#  Training loss 0.05430625285002954
#  Validation loss 2.0798640404686783
#
# Training Details
# training Accuracy = 0.9897959183673469
# Average Distance for 0 label = 0.08734237421525731
# Average Distance for 1 label = 5.569895507842302
#
# Validation Details
# Validation Accuracy = 0.5353535353535354
# Average Distance for 0 label = 1.6401217132806778
# Average Distance for 1 label = 26.451935122652753
#
# Starting training
# Starting Validation
# Epoch number 14
#  Training loss 0.08421803316703533
#  Validation loss 0.8579801333071005
#
# Training Details
# training Accuracy = 0.9868804664723032
# Average Distance for 0 label = 0.1022874637385883
# Average Distance for 1 label = 4.781669085216989
#
# Validation Details
# Validation Accuracy = 0.7474747474747475
# Average Distance for 0 label = 1.0829650818237238
# Average Distance for 1 label = 20.475316604902577
#
# Starting training
# Starting Validation
# Epoch number 15
#  Training loss 0.04767786701539573
#  Validation loss 0.6350493844259869
#
# Training Details
# training Accuracy = 0.9956268221574344
# Average Distance for 0 label = 0.11633937016242381
# Average Distance for 1 label = 4.832962483125791
#
# Validation Details
# Validation Accuracy = 0.8383838383838383
# Average Distance for 0 label = 0.9660023552306155
# Average Distance for 1 label = 18.64466816645402
#
# Starting training
# Starting Validation
# Epoch number 16
#  Training loss 0.09402727433187162
#  Validation loss 0.48802894145024545
#
# Training Details
# training Accuracy = 0.9854227405247813
# Average Distance for 0 label = 0.11533955221984354
# Average Distance for 1 label = 5.137039879992521
#
# Validation Details
# Validation Accuracy = 0.7777777777777778
# Average Distance for 0 label = 0.9626535718760839
# Average Distance for 1 label = 25.95294652725088
#
# Starting training
# Starting Validation
# Epoch number 17
#  Training loss 0.04565669560837885
#  Validation loss 0.17706734641934885
#
# Training Details
# training Accuracy = 0.9927113702623906
# Average Distance for 0 label = 0.06491913947151055
# Average Distance for 1 label = 4.810900987544019
#
# Validation Details
# Validation Accuracy = 0.9797979797979798
# Average Distance for 0 label = 0.47973546751265256
# Average Distance for 1 label = 18.175163034511648
#
# Starting training
# Starting Validation
# Epoch number 18
#  Training loss 0.06258943566010346
#  Validation loss 0.3669316005902459
#
# Training Details
# training Accuracy = 0.9897959183673469
# Average Distance for 0 label = 0.07159205835277238
# Average Distance for 1 label = 5.119096732643005
#
# Validation Details
# Validation Accuracy = 0.898989898989899
# Average Distance for 0 label = 0.7507985884204824
# Average Distance for 1 label = 21.860149933741642
#
# Starting training
# Starting Validation
# Epoch number 19
#  Training loss 0.06464838167556945
#  Validation loss 0.4032083009604854
#
# Training Details
# training Accuracy = 0.9883381924198251
# Average Distance for 0 label = 0.09091946357624471
# Average Distance for 1 label = 4.538356684861176
#
# Validation Details
# Validation Accuracy = 0.8686868686868687
# Average Distance for 0 label = 0.7642170141637326
# Average Distance for 1 label = 18.21450036885787
#
# Starting training
# Starting Validation
# Epoch number 20
#  Training loss 0.049711019009913954
#  Validation loss 0.28249027403165594
#
# Training Details
# training Accuracy = 0.9927113702623906
# Average Distance for 0 label = 0.0711199562686185
# Average Distance for 1 label = 5.9311055298551825
#
# Validation Details
# Validation Accuracy = 0.9191919191919192
# Average Distance for 0 label = 0.6784525653347373
# Average Distance for 1 label = 22.952523773791743
#
# Starting training
# Starting Validation
# Epoch number 21
#  Training loss 0.07348069281850751
#  Validation loss 0.4351762314185952
#
# Training Details
# training Accuracy = 0.9868804664723032
# Average Distance for 0 label = 0.10301849734639648
# Average Distance for 1 label = 4.771689528056809
#
# Validation Details
# Validation Accuracy = 0.8888888888888888
# Average Distance for 0 label = 0.797568045258522
# Average Distance for 1 label = 21.067913775541346
#
# Starting training
# Starting Validation
# Epoch number 22
#  Training loss 0.08234704867673633
#  Validation loss 1.5916686671212166
#
# Training Details
# training Accuracy = 0.9868804664723032
# Average Distance for 0 label = 0.11538543349654701
# Average Distance for 1 label = 7.204084566791416
#
# Validation Details
# Validation Accuracy = 0.8686868686868687
# Average Distance for 0 label = 1.1808765699204646
# Average Distance for 1 label = 27.49055130755315
#
# Starting training
